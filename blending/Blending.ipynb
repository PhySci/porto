# %%
import pandas as pd
import numpy as np
import joblib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def submit(predDf, fName = 'submission.csv'):
    """
    Write submission file.
    params:
        pred - predictions (array)
        ind - index for prediction (array)
        fName - name of file (string)
    """
    predDf.rename(columns={'prediction':'target'},inplace=True)
    predDf.to_csv(fName,index_label='id',float_format='%.6f')

# %%
fList = ['catModel1.dmp','xgbModel2.dmp']

# %%
c1 = joblib.load(fList[0])['test_prediction']
c1.columns = ['target']
c2 = joblib.load(fList[1])['test_prediction']

# %%
c1.head()
# Out:
#       target
# id
# 0   0.023346
# 1   0.025751
# 2   0.024386
# 3   0.014235
# 4   0.033721

# %%
c2.head()
# Out:
#       target
# id
# 0   0.042243
# 1   0.043655
# 2   0.038021
# 3   0.022985
# 4   0.055887

# %%
c = 0.5*(c1+c2)

# %%
submit(c,'blend1.csv')

# %% [markdown]
# PLB is 0.283

# %%
trainDf = pd.DataFrame()
testDf  = pd.DataFrame()

# %%
for fName in fList:
    dct = joblib.load(fName)
    trainDf.insert(0, fName, dct['train_prediction'].prediction)
    testDf.insert(0, fName, dct['test_prediction'])

# %%
testDf
# Out:
#         xgbModel2.dmp  catModel1.dmp
# 0            0.042243       0.023346
# 1            0.043655       0.025751
# 2            0.038021       0.024386
# 3            0.022985       0.014235
# 4            0.055887       0.033721
# 5            0.068505       0.046778
# 6            0.024037       0.018160
# 7                 NaN            NaN
# 8            0.055165       0.034095
# 9                 NaN            NaN
# 10           0.077307       0.050095
# 11           0.090465       0.054802
# 12           0.044877       0.034002
# 13                NaN            NaN
# 14           0.037109       0.024584
# 15           0.067440       0.043818
# 16                NaN            NaN
# 17                NaN            NaN
# 18           0.064836       0.047224
# 19                NaN            NaN
# 20                NaN            NaN
# 21           0.066381       0.047816
# 22                NaN            NaN
# 23           0.034596       0.023114
# ...

# %%
trainDf.head()
# Out:
#     xgbModel2.dmp  catModel1.dmp
# id
# 7        0.063895       0.042122
# 9        0.048852       0.030500
# 13       0.032510       0.019126
# 16       0.029717       0.016305
# 17       0.059475       0.035986

# %%
labelDf = joblib.load('labels.dmp')

# %%
trainDf.insert(0,'target',labelDf)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(trainDf.drop("target", axis = 1), trainDf.target)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
testDf.dropna(inplace=True)

# %%
d

# %%
y = pd.DataFrame(data= lr.predict_proba(testDf)[:,1],
             index= testDf.index, columns= ['target'])

# %%
submit(y,'blend3.csv')

# %%
dct['test_prediction'].shape
# Out:
# (892816, 1)

# %%
y.shape
# Out:
# (535474, 1)
